# %%
import os
import json
from googleapiclient.discovery import build
from google.oauth2 import service_account

# %%
# Ganti dengan path ke credential file Anda
SERVICE_ACCOUNT_FILE = 'path/to/service-account.json'
SCOPES = ['https://www.googleapis.com/auth/drive.file']

# Autentikasi ke Google Drive
creds = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
drive_service = build('drive', 'v3', credentials=creds)

def merge_json_files(directory):
    merged_data = []
    
    # Iterasi melalui semua file JSON dalam direktori
    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            filepath = os.path.join(directory, filename)
            with open(filepath, 'r') as f:
                data = json.load(f)
                merged_data.extend(data)  # Gabungkan data

    # Simpan ke file baru 'kabarbursa.json'
    with open(os.path.join(directory, 'kabarbursa.json'), 'w') as f:
        json.dump(merged_data, f)

def upload_to_drive(file_name, folder_id):
    file_metadata = {
        'name': file_name,
        'parents': [folder_id]
    }
    media = MediaFileUpload(os.path.join(directory, file_name), mimetype='application/json')
    drive_service.files().create(body=file_metadata, media_body=media, fields='id').execute()

# Merging JSON files
directory = './data/'
merge_json_files(directory)

# Upload merged file to Google Drive
upload_to_drive('kabarbursa.json', 'YOUR_FOLDER_ID')
