# %%
# Loaded variable 'df' from URI: /Users/albert/Documents/Finances/projects/01_data_engineering/scraper_information_disclosure/data/idx_disclosures_20260210_233230.csv
import pandas as pd
df = pd.read_csv('/Users/albert/Documents/Finances/projects/01_data_engineering/scraper_information_disclosure/data/idx_disclosures_20260210_233230.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0)        # auto fit ke lebar terminal VS Code
pd.set_option('display.max_colwidth', None)
