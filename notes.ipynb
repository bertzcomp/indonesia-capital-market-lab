# %%
# !tree -f -L 10
# Out:
# .
# ├── ./README.md
# ├── ./anon.session
# ├── ./data
# │   ├── ./data/externals
# │   │   ├── ./data/externals/Podcast LH ft. HA
# │   │   │   ├── ./data/externals/Podcast LH ft. HA/Perjalanan Open Porto Menuju Rp 100 Miliar - ft. Hengky Adinata
# │   │   │   └── ./data/externals/Podcast LH ft. HA/Perjalanan Open Porto Menuju Rp 100 Miliar - ft. Hengky Adinata [Indonesian (auto-generated)] [DownloadYoutubeSubtitles.com].txt
# │   │   ├── ./data/externals/books
# │   │   │   ├── ./data/externals/books/How to Build Your Own Algorithmic Trading Business.pdf
# │   │   │   └── ./data/externals/books/Paul Wilmott on Quantitative Finance.pdf
# │   │   ├── ./data/externals/chatgpt
# │   │   │   └── ./data/externals/chatgpt/Analisis Potensi Bagger.md
# │   │   ├── ./data/externals/scalping trade
# │   │   │   ├── ./data/externals/scalping trade/ILMU SCALPING SAHAM (HENGKY ADINATA TRADER).txt
# │   │   │   └── ./data/externals/scalping trade/Tape Reading Untuk Scalping | IPOT x Om Ben.md
# ...
