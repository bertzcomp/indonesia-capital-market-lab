# %%
import pandas as pd


df = pd.read_parquet("master_dataset.parquet")
display(df)

print(df.columns)
# Out:
#               date ticker          open          high           low  \
# 0       2015-01-02   AALI  16715.333882  17196.845842  16680.940171
# 1       2015-01-02   ABBA     48.466820     50.055897     48.466820
# 2       2015-01-02   ABDA   5533.175293   5533.175293   5533.175293
# 3       2015-01-02   ABMM   2110.177002   2110.177002   2110.177002
# 4       2015-01-02   ACES    576.700535    580.373786    569.354031
# ...            ...    ...           ...           ...           ...
# 1906999 2026-03-06   ZATA    133.000000    133.000000    133.000000
# 1907000 2026-03-06   ZBRA     50.000000      0.000000      0.000000
# 1907001 2026-03-06   ZINC     35.000000     35.000000     34.000000
# 1907002 2026-03-06   ZONE    466.000000    476.000000    440.000000
# 1907003 2026-03-06   ZYRX    149.000000    149.000000    146.000000
#
#                 close      volume         source_file source_month  \
# 0        16904.500000   1385945.0                None         None
# ...

# %%
listed_shares = pd.read_csv("data/listed_shares/listed_shares.csv")
listed_shares
# Out:
#                date ticker  close  listed_shares      market_cap  \
# 0        2020-01-02   AALI  14025     1924688333  26993753870325
# 1        2020-01-02   ABBA    105     2755125000    289288125000
# 2        2020-01-02   ABDA   6925      620806680   4299086259000
# 3        2020-01-02   ABMM   1530     2753165000   4212342450000
# 4        2020-01-02   ACES   1510    17150000000  25896500000000
# ...             ...    ...    ...            ...             ...
# 1280524  2026-03-06   ZATA    133     8496000000   1129968000000
# 1280525  2026-03-06   ZBRA     50     2510706263    125535313150
# 1280526  2026-03-06   ZINC     35    25250000000    883750000000
# 1280527  2026-03-06   ZONE    466      870171478    405499908748
# 1280528  2026-03-06   ZYRX    148     1333334556    197333514288
#
#                      source_file source_month
# 0        all_2020_market_cap.csv   market_cap
# 1        all_2020_market_cap.csv   market_cap
# ...

# %%
ohlcv = pd.read_csv("data/ohlcv/ohlcv.csv")
ohlcv
# Out:
# /var/folders/pt/n4kz04ns6wn8sv6msgx6mqb80000gn/T/ipykernel_23059/2565488563.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   ohlcv = pd.read_csv("data/ohlcv/ohlcv.csv")
#                date ticker          open          high           low  \
# 0        2015-01-02   AALI  16715.333882  17196.845842  16680.940171
# 1        2015-01-05   AALI  16921.693891  16990.481305  16749.725357
# 2        2015-01-06   AALI  16904.506029  16904.506029  16629.356240
# 3        2015-01-07   AALI  16715.332749  16990.482422  16715.332749
# 4        2015-01-08   AALI  17093.667511  17454.802245  17093.667511
# ...             ...    ...           ...           ...           ...
# 2001168  2026-03-06   ZATA      0.000000    133.000000    133.000000
# 2001169  2026-03-06   ZBRA      0.000000      0.000000      0.000000
# 2001170  2026-03-06   ZINC      0.000000     35.000000     34.000000
# ...
